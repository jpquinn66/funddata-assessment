# %% [markdown]
# ## Exercise 1
# ***

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the morley data set
data = pd.read_csv("Morley.csv")
# Out:
#     Unnamed: 0  Expt  Run  Speed
# 0            1     1    1    850
# 1            2     1    2    740
# 2            3     1    3    900
# 3            4     1    4   1070
# 4            5     1    5    930
# ..         ...   ...  ...    ...
# 95          96     5   16    940
# 96          97     5   17    950
# 97          98     5   18    800
# 98          99     5   19    810
# 99         100     5   20    870
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Exercise 2
# ***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the iris data set
iris = sns.load_dataset("iris")

# Create a figure and a set of subplots
fig, axs = plt.subplots(2, 2)

# Create a box plot for each numerical variable
sns.boxplot(data=iris, x="species", y="sepal_length", ax=axs[0][0])
sns.boxplot(data=iris, x="species", y="sepal_width", ax=axs[0][1])
sns.boxplot(data=iris, x="species", y="petal_length", ax=axs[1][0])
sns.boxplot(data=iris, x="species", y="petal_width", ax=axs[1][1])

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 3
# ***

# %%
# Create a series of x vectors.
xs = np.array([np.linspace(i, i + 2.0, 20) for i in range(10)])
# Create a corresponding series of y vectors.
ys = np.array([xs[i] for i in range(len(xs))])

# Add some noise.
ys = ys + np.random.normal(0.0, 1.0, ys.shape)
# Create global list of x and y values.
x = xs.flatten()
y = ys.flatten()
# Plot 1/y instead of y to make the overall plot inversely proportional.
plt.plot(x, 1/y, '.');

# %%
# Best fit line slope and y intercept.
m, c = np.polyfit(x, y, 1)
# Create a steadily increasing x range for plotting.
xbestfit = np.linspace(x.min(), x.max(), 1000)
# Create corresponding y values form best fit line.
ybestfit = m * xbestfit + c
# Plot points.
plt.plot(x, y, '.')

# Plot line.
plt.plot(xbestfit, 1/ybestfit);
